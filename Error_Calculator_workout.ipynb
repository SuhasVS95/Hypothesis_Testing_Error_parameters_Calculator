# %% [markdown]
# ## <center>Error Parameters Calculator</center>

# %% [markdown]
# ### Problem Statement:
#
# This error calculator function calculates the different parameter with the given data. The parameters include:
#
# **1. Sample Size(n)**<br>
# **2. Type I Error(alpha)**<br>
# **3. Type II Error(beta)**<br>
# **4. Population Mean**<br>
# **5. Sample Mean**<br>
# **6. Population Standard Deviation**<br>
#
# **How does it work?**
#
# 1. Select the error parameter number from above list.
# 2. Enter the asked required data.
# 3. Get the calculated output of the required parameter.
# 4. Repeat steps 1,2,3 for different parameters to be calculated continuing the code.
# 5. When you wish to quit select "n".

# %%
# installing the library
pip install error-param-cal
# Out:
# Requirement already satisfied: error-param-cal in f:\ana3\lib\site-packages (0.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing the library
from error_parameters_calculator import error_param

# %%
# just run the required parameter method of "error_parameters_calculator" to get individual parameter workout. Refer below:
import error_parameters_calculator

#error_parameters_calculator.calculate_alpha()
#error_parameters_calculator.calculate_beta()
#error_parameters_calculator.calculate_population_mean()
#error_parameters_calculator.calculate_sample_mean()
#error_parameters_calculator.calculate_sample_size()
#error_parameters_calculator.calculate_sigma()

# For example
error_parameters_calculator.calculate_population_mean()
# Out:
# Required parameters for population mean calculation:
# --------------------------------------------------------------------------
# Enter alpha value:0.01
# Enter sample size value:40
# Enter sigma value:1.7
# Enter beta value:0.32
# Enter sample mean value:17.5
# Calculated Z_Alpha: 2.3263478740408408
# Calculated Z_Beta: -0.46769879911450823
# --------------------------------------------------------------------------
# The population mean for your above requirement of parameters is: 18.0
# --------------------------------------------------------------------------

# %%
# Just call the function to start calculating
error_param()
# Out:
# Hi!!! Welcome to ERROR CALCULATOR. We will help you to calculate your required error parameters.
#
# Please select the number of the respective parameter you like to calculate:
#
# 1. Sample Size(n)
#
# 2. Type I Error(alpha)
#
# 3. Type II Error(beta)
#
# 4. Population Mean
#
# 5. Sample Mean
#
#  6.Sigma
# --------------------------------------------------------------------------
# Enter the number:1
# Required parameters for sample size calculation:
# --------------------------------------------------------------------------
# Enter alpha value:0.01
# Enter beta value:0.32
# Enter sigma value:1.7
# Enter population mean value:18
# Enter sample mean value:17.5
# Calculated Z_Alpha: 2.3263478740408408
# Calculated Z_Beta: -0.46769879911450823
# --------------------------------------------------------------------------
# The sample size for your above requirement of parameters is: 40.0
# --------------------------------------------------------------------------
# Do you want to continue:y/n
# y
# Please select the number of the respective parameter you like to calculate:
#
# 1. Sample Size(n)
#
# 2. Type I Error(alpha)
#
# 3. Type II Error(beta)
#
# 4. Population Mean
#
# 5. Sample Mean
#
#  6.Sigma
# --------------------------------------------------------------------------
# Enter the number:2
# Required parameters for alpha calculation:
# --------------------------------------------------------------------------
# Enter beta value:0.32
# Enter sample size value:40
# Enter sigma value:1.7
# Enter population mean value:18
# Enter sample mean value:17.5
# Calculated Z_Alpha: 2.32786212862532
# Calculated Z_Beta: -0.46769879911450823
# --------------------------------------------------------------------------
# The Type I error(alpha) for your above requirement of parameters is: 0.01
# --------------------------------------------------------------------------
# Do you want to continue:y/n
# y
# Please select the number of the respective parameter you like to calculate:
#
# 1. Sample Size(n)
#
# 2. Type I Error(alpha)
#
# 3. Type II Error(beta)
#
# 4. Population Mean
#
# 5. Sample Mean
#
#  6.Sigma
# --------------------------------------------------------------------------
# Enter the number:3
# Required parameters for beta calculation:
# --------------------------------------------------------------------------
# Enter alpha value:0.01
# Enter sample size value:40
# Enter sigma value:1.7
# Enter population mean value:18
# Enter sample mean value:17.5
# Calculated Z_Alpha: 2.3263478740408408
# Calculated Z_Beta: -0.4661845445300292
# --------------------------------------------------------------------------
# The Type II error(beta) for your above requirement of parameters is: 0.32
# --------------------------------------------------------------------------
# Do you want to continue:y/n
# y
# Please select the number of the respective parameter you like to calculate:
#
# 1. Sample Size(n)
#
# 2. Type I Error(alpha)
#
# 3. Type II Error(beta)
#
# 4. Population Mean
#
# 5. Sample Mean
#
#  6.Sigma
# --------------------------------------------------------------------------
# Enter the number:4
# Required parameters for population mean calculation:
# --------------------------------------------------------------------------
# Enter alpha value:0.01
# Enter sample size value:40
# Enter sigma value:1.7
# Enter beta value:0.32
# Enter sample mean value:17.5
# Calculated Z_Alpha: 2.3263478740408408
# Calculated Z_Beta: -0.46769879911450823
# --------------------------------------------------------------------------
# The population mean for your above requirement of parameters is: 18.0
# --------------------------------------------------------------------------
# Do you want to continue:y/n
# y
# Please select the number of the respective parameter you like to calculate:
#
# 1. Sample Size(n)
#
# 2. Type I Error(alpha)
#
# 3. Type II Error(beta)
#
# 4. Population Mean
#
# 5. Sample Mean
#
#  6.Sigma
# --------------------------------------------------------------------------
# Enter the number:5
# Required parameters for sample mean calculation:
# --------------------------------------------------------------------------
# Enter alpha value:0.01
# Enter sample size value:40
# Enter sigma value:1.7
# Enter beta value:0.32
# Enter population mean value:18
# Calculated Z_Alpha: 2.3263478740408408
# Calculated Z_Beta: -0.46769879911450823
# --------------------------------------------------------------------------
# The sample mean for your above requirement of parameters is: 17.5
# --------------------------------------------------------------------------
# Do you want to continue:y/n
# y
# Please select the number of the respective parameter you like to calculate:
#
# 1. Sample Size(n)
#
# 2. Type I Error(alpha)
#
# 3. Type II Error(beta)
#
# 4. Population Mean
#
# 5. Sample Mean
#
#  6.Sigma
# --------------------------------------------------------------------------
# Enter the number:6
# Required parameters for sigma calculation:
# --------------------------------------------------------------------------
# Enter alpha value:0.01
# Enter sample size value:40
# Enter beta value:0.32
# Enter sample mean value:17.5
# Enter population mean value:18
# Calculated Z_Alpha: 2.3263478740408408
# Calculated Z_Beta: -0.46769879911450823
# --------------------------------------------------------------------------
# The population std for your above requirement of parameters is: 1.7
# --------------------------------------------------------------------------
# Do you want to continue:y/n
# n
#
# You have opted to quit.
# Thank you for using the Error Calculator
